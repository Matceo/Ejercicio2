# %% [markdown]
# <a href="https://colab.research.google.com/github/Matceo/SyS./blob/main/S%26S%3ASe%C3%B1alesDeEnerg%C3%ADa%26Potencia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Circuito con impedancia R+jwL

from numpy import *
import matplotlib.pyplot as plt

R=5
L=0.06
W=200
wl=W*L
V_max=10
F=100/pi
T=1/F
Fs=100*F
Ts=1/Fs
t=arange(0, T, Ts)
v=V_max*sin(W*t)
I_max=V_max/R
theta=round(arctan(wl/R), 2)
i=I_max*sin(W*t-theta)
p=v*i
Pm=round(trapz(p, t)/T, 3)
plt.figure(figsize=[10,5])
plt.plot(t, p, label='Potencia Instantanea')
plt.plot(t, Pm*ones(len(t)), 'r', label='Potencia Media')
plt.grid()
plt.legend()
plt.xlabel('t')
plt.ylabel('Amplitud')
plt.show()
