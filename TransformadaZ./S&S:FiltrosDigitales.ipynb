# %% [markdown]
# <a href="https://colab.research.google.com/github/Matceo/SyS./blob/main/TransformadaZ./S%26S%3AFiltrosDigitales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Ejercicio1

# !python3 -m pip install --force-reinstall https://github.com/yt-dlp/yt-dlp/archive/master.tar.gz

cancion="https://www.youtube.com/watch?v=WDcuccjJbAk"
# !yt-dlp --extract-audio -o "cancion" --audio-format mp3 {cancion}
# !ffmpeg -i cancion.mp3 output.wav
# !pip install soundfile
import soundfile as sf #Para instalar pip install soundfile
nombre_out="output.wav" #Para leer archivos .wav
x, fs=sf.read(nombre_out)
print('Frecuencia de Muestreo %.2f[Hz]\naudio %s' % (fs, nombre_out))
x.shape[0]/fs
xpro=x.copy() #Copiar los archivos para procesar
ti=40
tf=50
xs=xpro[int(ti*fs):int((tf*fs)), :]

from IPython.display import Audio #Para escuchar el trozo de audio con el que se va a trabajar; no usar un trozo muy grande o el entorno se puede desconectar

Audio([xs[:, 1], xs[:, 0]], rate=fs)
x2=x.copy()
ti=63
tf=ti+10
xs=x2[int(ti*fs):int((tf*fs)), :]
K=int(len(xs)/2)+1
Audio([xs[:, 1], xs[:, 0]], rate=fs) #segmento de audio

#Diseño del filtro pasabanda:

from scipy.signal import butter, cheby1, cheby2, bessel, ellip, lfilter, freqz, firwin
import matplotlib.pyplot as plt
import numpy as np

#Filtro Butterworth a la canción:

filt='bandpass' #Tipo del filtro (pasa-baja, pasa-alta, pasabanda, rechazabanda)
print('\t\tFiltro Pasabanda Butterworth')
N=int(input('\nIngrese el orden del filtro que desea: '))
print('El orden del filtro que usted eleigio es de: ', N)
Wn=[] #Banda pasante

#Le pedimos al usuario que ingrese elementos y los agregamos a la lista:

ele_uno=int(input("\nIngrese la frecuencia de corte inferior: "))
ele_dos=int(input("Ingrese la frecuencia de corte superior: "))
Wn.append(ele_uno)
Wn.append(ele_dos)

#Imprimir la banda pasante:

print("Banda Pasante= ", Wn)
b, a=butter(N, Wn=Wn, btype=filt, fs=fs)
xf=lfilter(b, a, xs, axis=0)
Audio([xf[:, 1], xf[:, 0]], rate=fs) #Audio con ruido filtrado

#Filtro Chebyshev 1 a la canción:

filt='bandpass' #Tipo del filtro (pasa-baja, pasa-alta, pasabanda, rechazabanda)
print('\t\tFiltro Pasabanda Chebyshev 1')
N = int(input('\nIngrese el orden del filtro que desea: '))
print('El orden del filtro que usted eleigio es de: ', N)
Wn=[] #Banda pasante

#Le pedimos al usuario que ingrese elementos y los agregamos a la lista:

ele_uno=int(input("\nIngrese la frecuencia de corte inferior: "))
ele_dos=int(input("Ingrese la frecuencia de corte superior: "))
Wn.append(ele_uno)
Wn.append(ele_dos)

#Imprimir la banda pasante:

print("Banda Pasante= ", Wn)
ripple=int(input("\nIngrese su valor de ripple: "))
print("ripple: ", ripple)
b, a=cheby1(N, rp=ripple, Wn=Wn, btype=filt, fs=fs)
xf=lfilter(b, a, xs, axis=0)
Audio([xf[:, 1], xf[:,0]], rate=fs) #Audio con ruido filtrado

#Filtro Chebyshev 2 a la canción:

filt='bandpass' #Tipo del filtro (pasa-baja, pasa-alta, pasabanda, rechazabanda)
print('\t\tFiltro Pasabanda Chebyshev 2')
N=int(input('\nIngrese el orden del filtro que desea: '))
print('El orden del filtro que usted eleigio es de: ', N)
Wn=[]#Banda pasante

#Le pedimos al usuario que ingrese elementos y los agregamos a la lista:

ele_uno=int(input("\nIngrese la frecuencia de corte inferior: "))
ele_dos=int(input("Ingrese la frecuencia de corte superior: "))
Wn.append(ele_uno)
Wn.append(ele_dos)

#Imprimir la banda pasante:

print("Banda Pasante= ", Wn)
ripple=int(input("\nIngrese su valor de ripple: "))
print("ripple: ", ripple)
b, a=cheby2(N, rs=ripple, Wn=Wn, btype=filt, fs=fs)
xf=lfilter(b, a, xs, axis=0)
Audio([xf[:, 1], xf[:, 0]], rate=fs) #Audio con ruido filtrado

#Filtro Bessel a la canción:

filt='bandpass' #Tipo del filtro (pasa-baja, pasa-alta, pasabanda, rechazabanda)
print('\t\tFiltro Pasabanda Bessel')
N = int(input('\nIngrese el orden del filtro que desea: '))
print('El orden del filtro que usted eleigio es de: ', N)
Wn=[] #Banda pasante

#Le pedimos al usuario que ingrese elementos y los agregamos a la lista:

ele_uno=int(input("\nIngrese la frecuencia de corte inferior: "))
ele_dos=int(input("Ingrese la frecuencia de corte superior: "))
Wn.append(ele_uno)
Wn.append(ele_dos)

#Imprimir la banda pasante:

print("Banda Pasante=", Wn)
normalization='mag' #Ajusta la frecuencia crítica según la respuesta que se desea
num, den=bessel(N, Wn=Wn, btype=filt, norm=normalization, fs=fs) #Regresa el numerador y denominador. Si se quiere obtener los polos y ceros usar scipy.signal.tf2zpk
xf=lfilter(num, den, xs, axis=0)
Audio([xf[:, 1], xf[:, 0]], rate=fs) #Audio con ruido filtrado

#Filtro Elíptico a la canción:

filt='bandpass' #Tipo del filtro (pasa-baja, pasa-alta, pasabanda, rechazabanda)
print('\t\tFiltro Pasabanda Elíptico')
N=int(input('\nIngrese el orden del filtro que desea: '))
print('El orden del filtro que usted eleigio es de: ', N)
Wn=[]#Banda pasante

#Le pedimos al usuario que ingrese elementos y los agregamos a la lista:

ele_uno=int(input("\nIngrese la frecuencia de corte inferior: "))
ele_dos=int(input("Ingrese la frecuencia de corte superior: "))
Wn.append(ele_uno)
Wn.append(ele_dos)

#Imprimir la banda pasante:

print("Banda Pasante= ", Wn)
ripple_pass=int(input("\nIngrese su valor de ripple pass: "))
ripple_stop=int(input("Ingrese su valor de ripple stop: "))
num, den=ellip(N, rp=ripple_pass, rs=ripple_stop, Wn=Wn, btype=filt, fs=fs) #Regresa el numerador y denominador. Si se quiere obtener los polos y ceros usar scipy.signal.tf2zpk
xf=lfilter(num, den, xs, axis=0)
Audio([xf[:, 1], xf[:, 0]], rate=fs) #Audio con ruido filtrado

#Ejercicio3

# !python3 -m pip install --force-reinstall https://github.com/yt-dlp/yt-dlp/archive/master.tar.gz
cancion="https://www.youtube.com/watch?v=WDcuccjJbAk"
# !yt-dlp --extract-audio -o "cancion" --audio-format mp3 {cancion}
# !ffmpeg -i cancion.mp3 output.wav
# !pip install soundfile

import soundfile as sf #Para instalar pip install soundfile

nombre_out="output.wav" #Para leer archivos wav
x, fs=sf.read(nombre_out)
print('Frecuencia de Muestreo %.2f[Hz]\naudio %s' % (fs, nombre_out))
x.shape[0]/fs
xpro=x.copy() #Copiar los archivos para procesar
ti=40
tf=50
xs=xpro[int(ti*fs):int((tf*fs)), :]

from IPython.display import Audio #Para escuchar el trozo de audio con el que se va a trabajar; no usar un trozo muy grande o el entorno se puede desconectar

Audio([xs[:, 1], xs[:, 0]], rate=fs)
x2=x.copy()
ti=63
tf=ti+10
xs=x2[int(ti*fs):int((tf*fs)), :]
K=int(len(xs)/2)+1
Audio([xs[:, 1], xs[:, 0]], rate=fs) #Segmento de audio

from scipy.signal import butter, cheby1, cheby2, bessel, ellip, lfilter, freqz, firwin
import matplotlib.pyplot as plt
import numpy as np

filt='bandpass' #Tipo del filtro (pasa-baja, pasa-alta, pasabanda, rechazabanda)
print('\t\tFiltro Pasabanda Firwin')
N=int(input('\nIngrese el orden del filtro que desea: '))
print('El orden del filtro que usted eleigio es de: ', N)
Wn=[] #Banda pasante

#Le pedimos al usuario que ingrese elementos y los agregamos a la lista:

ele_uno=int(input("\nIngrese la frecuencia de corte inferior: "))
ele_dos=int(input("Ingrese la frecuencia de corte superior: "))
Wn.append(ele_uno)
Wn.append(ele_dos)

#Imprimir la banda pasante:

print("Banda Pasante= ", Wn)
fir_coeff=firwin(N, Wn, fs=fs, window='hamming')
xf=lfilter(fir_coeff, 4.0, xs, axis=0)
Audio([xf[:, 1], xf[:, 0]], rate=fs) #Audio con ruido filtrado
